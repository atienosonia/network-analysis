# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('#MamaMbogaMoment - Sheet .csv')
df.head()
# Out:
#                       Date                                              Title  \
# 0  2022-07-19 16:47:28.000  RT @HMureithi @Kenyans This is too low for a m...
# 1  2022-07-10 16:21:50.000  RT @kilundeezy A good reminder  @OleItumbi  pa...
# 2  2022-07-10 14:36:50.000  RT @kilundeezy A good reminder  @OleItumbi  pa...
# 3  2022-07-09 15:45:27.000  RT @kilundeezy A good reminder  @OleItumbi  pa...
# 4  2022-07-09 12:34:16.000  RT @kilundeezy A good reminder  @OleItumbi  pa...
#
#                                            Full Text Sentiment Emotion  \
# 0  RT @HMureithi @Kenyans This is too low for a m...  negative     NaN
# 1  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral     NaN
# 2  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral     NaN
# 3  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral     NaN
# 4  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral     NaN
#
#         Region    Account Type        Author     City  \
# 0          NaN      individual        mngesa      NaN
# 1      Nairobi      individual   Olang_Moses  Nairobi
# 2      Nairobi      individual  CaesarToreto  Nairobi
# 3      Nairobi  organisational  kirubimuigai  Nairobi
# 4  Rift Valley      individual   125__iconic  Kericho
#
#                      Full Name  ...          Mentioned Authors Priority  \
# 0             mngesa (sir ali)  ...       @hmureithi, @kenyans      NaN
# 1  Olang_Moses (MACHIAVELLIAN)  ...  @oleitumbi, @williamsruto      NaN
# 2          CaesarToreto (Czar)  ...  @oleitumbi, @williamsruto      NaN
# 3   kirubimuigai (Sports IHub)  ...  @oleitumbi, @williamsruto      NaN
# 4         125__iconic (yusufu)  ...  @oleitumbi, @williamsruto      NaN
#
#                                      Professions              Tags  \
# 0                                            NaN  #MamaMbogaMoment
# 1                                            NaN  #MamaMbogaMoment
# 2  Sales/Marketing/PR (Digital Media Strategist)  #MamaMbogaMoment
# 3                                            NaN  #MamaMbogaMoment
# 4                                            NaN  #MamaMbogaMoment
#
#   Total Monthly Visitors Twitter Author ID  Twitter Followers  \
# 0             1414667000      1.342399e+08                 32
# 1             1414667000      4.083459e+09              21114
# 2             1414667000      1.357592e+18              10073
# 3             1414667000      7.296242e+17                221
# 4             1414667000      1.533716e+18                342
#
#   Twitter Following Twitter Tweets  Reach (new)
# 0               159            462            0
# 1             15120         157903         7602
# 2              1209          32910         4958
# 3                34           8326            0
# 4               183           1705            0
#
# [5 rows x 25 columns]

# %%
# shape
print(df.shape)

# columns
print(df.columns)
# Out:
# (2396, 25)
# Index(['Date', 'Title', 'Full Text', 'Sentiment', 'Emotion', 'Region',
#        'Account Type', 'Author', 'City', 'Full Name', 'Gender', 'Hashtags',
#        'Impact', 'Impressions', 'Interest', 'Mentioned Authors', 'Priority',
#        'Professions', 'Tags', 'Total Monthly Visitors', 'Twitter Author ID',
#        'Twitter Followers', 'Twitter Following', 'Twitter Tweets',
#        'Reach (new)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2396 entries, 0 to 2395
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    2396 non-null   object
#  1   Title                   2396 non-null   object
#  2   Full Text               2396 non-null   object
#  3   Sentiment               2396 non-null   object
#  4   Emotion                 1084 non-null   object
#  5   Region                  2128 non-null   object
#  6   Account Type            2395 non-null   object
#  7   Author                  2396 non-null   object
#  8   City                    2087 non-null   object
#  9   Full Name               2396 non-null   object
#  10  Gender                  2334 non-null   object
#  11  Hashtags                2395 non-null   object
#  12  Impact                  2396 non-null   float64
#  13  Impressions             2396 non-null   int64
#  14  Interest                1211 non-null   object
#  15  Mentioned Authors       1433 non-null   object
#  16  Priority                0 non-null      float64
#  17  Professions             523 non-null    object
#  18  Tags                    2396 non-null   object
#  19  Total Monthly Visitors  2396 non-null   int64
#  20  Twitter Author ID       2395 non-null   float64
#  21  Twitter Followers       2396 non-null   int64
#  22  Twitter Following       2396 non-null   int64
#  23  Twitter Tweets          2396 non-null   int64
#  24  Reach (new)             2396 non-null   int64
# dtypes: float64(3), int64(6), object(16)
# memory usage: 468.1+ KB

# %%
# duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# lower the columns
df.columns = [column.lower() for column in df.columns]

# %%
df.head(2)
# Out:
#                       date                                              title  \
# 0  2022-07-19 16:47:28.000  RT @HMureithi @Kenyans This is too low for a m...
# 1  2022-07-10 16:21:50.000  RT @kilundeezy A good reminder  @OleItumbi  pa...
#
#                                            full text sentiment emotion  \
# 0  RT @HMureithi @Kenyans This is too low for a m...  negative     NaN
# 1  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral     NaN
#
#     region account type       author     city                    full name  \
# 0      NaN   individual       mngesa      NaN             mngesa (sir ali)
# 1  Nairobi   individual  Olang_Moses  Nairobi  Olang_Moses (MACHIAVELLIAN)
#
#    ...          mentioned authors priority  professions              tags  \
# 0  ...       @hmureithi, @kenyans      NaN          NaN  #MamaMbogaMoment
# 1  ...  @oleitumbi, @williamsruto      NaN          NaN  #MamaMbogaMoment
#
#   total monthly visitors twitter author id  twitter followers  \
# 0             1414667000      1.342399e+08                 32
# 1             1414667000      4.083459e+09              21114
#
#   twitter following twitter tweets  reach (new)
# 0               159            462            0
# 1             15120         157903         7602
#
# [2 rows x 25 columns]

# %%
# replace spaces with underscores
df.columns = [column.replace(' ', '_') for column in df.columns]

# %%
df.columns
# Out:
# Index(['date', 'title', 'full_text', 'sentiment', 'emotion', 'region',
#        'account_type', 'author', 'city', 'full_name', 'gender', 'hashtags',
#        'impact', 'impressions', 'interest', 'mentioned_authors', 'priority',
#        'professions', 'tags', 'total_monthly_visitors', 'twitter_author_id',
#        'twitter_followers', 'twitter_following', 'twitter_tweets',
#        'reach_(new)'],
#       dtype='object')

# %%
# check if the two columns title and full_text have the same content
df['title'].equals(df['full_text'])
# Out:
# False

# %%
# most mentioned names in the author section
df['author'].value_counts()
# Out:
# author
# Jonngc             32
# SelinaTeyie        23
# miguelmuguchia     17
# azimio022          15
# kelvin_mwebia      14
#                    ..
# obieroh_s           1
# LukaleMark          1
# mitpiny             1
# sonamoz             1
# Apologistmirror     1
# Name: count, Length: 1379, dtype: int64

# %%
# check if author and full name have the same content
df['author'].equals(df['full_name'])
# Out:
# False

# %%
df.columns
# Out:
# Index(['date', 'title', 'full_text', 'sentiment', 'emotion', 'region',
#        'account_type', 'author', 'city', 'full_name', 'gender', 'hashtags',
#        'impact', 'impressions', 'interest', 'mentioned_authors', 'priority',
#        'professions', 'tags', 'total_monthly_visitors', 'twitter_author_id',
#        'twitter_followers', 'twitter_following', 'twitter_tweets',
#        'reach_(new)'],
#       dtype='object')

# %%
# drop columns full_name, interest, priority, professions, total monthly visits 
df.drop(['full_name', 'interest', 'priority', 'professions'], axis = 1, inplace = True)

# %%
df.head(2)
# Out:
#                       date                                              title  \
# 0  2022-07-19 16:47:28.000  RT @HMureithi @Kenyans This is too low for a m...
# 1  2022-07-10 16:21:50.000  RT @kilundeezy A good reminder  @OleItumbi  pa...
#
#                                            full_text sentiment emotion  \
# 0  RT @HMureithi @Kenyans This is too low for a m...  negative     NaN
# 1  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral     NaN
#
#     region account_type       author     city   gender  ... impact  \
# 0      NaN   individual       mngesa      NaN     male  ...    0.0
# 1  Nairobi   individual  Olang_Moses  Nairobi  unknown  ...   38.9
#
#    impressions          mentioned_authors              tags  \
# 0           32       @hmureithi, @kenyans  #MamaMbogaMoment
# 1        21114  @oleitumbi, @williamsruto  #MamaMbogaMoment
#
#   total_monthly_visitors  twitter_author_id  twitter_followers  \
# 0             1414667000       1.342399e+08                 32
# 1             1414667000       4.083459e+09              21114
#
#    twitter_following  twitter_tweets  reach_(new)
# 0                159             462            0
# 1              15120          157903         7602
#
# [2 rows x 21 columns]

# %%
# drop the date column
df.drop('date', axis = 1, inplace = True)

# %%
# set index to twitter ID
df.set_index('twitter_author_id', inplace = True)

# %%
df.head(3)
# Out:
#                                                                title  \
# twitter_author_id
# 1.342399e+08       RT @HMureithi @Kenyans This is too low for a m...
# 4.083459e+09       RT @kilundeezy A good reminder  @OleItumbi  pa...
# 1.357592e+18       RT @kilundeezy A good reminder  @OleItumbi  pa...
#
#                                                            full_text  \
# twitter_author_id
# 1.342399e+08       RT @HMureithi @Kenyans This is too low for a m...
# 4.083459e+09       RT @kilundeezy A good reminder @OleItumbi pay ...
# 1.357592e+18       RT @kilundeezy A good reminder @OleItumbi pay ...
#
#                   sentiment emotion   region account_type        author  \
# twitter_author_id
# 1.342399e+08       negative     NaN      NaN   individual        mngesa
# 4.083459e+09        neutral     NaN  Nairobi   individual   Olang_Moses
# 1.357592e+18        neutral     NaN  Nairobi   individual  CaesarToreto
#
#                       city   gender  \
# twitter_author_id
# 1.342399e+08           NaN     male
# 4.083459e+09       Nairobi  unknown
# 1.357592e+18       Nairobi  unknown
#
#                                                             hashtags  impact  \
# twitter_author_id
# 1.342399e+08                                        #mamambogamoment     0.0
# 4.083459e+09       #mamambogamoment, #bottomupmuranga, #nyerinihu...    38.9
# 1.357592e+18       #mamambogamoment, #bottomupmuranga, #nyerinihu...    31.8
#
#                    impressions          mentioned_authors              tags  \
# twitter_author_id
# 1.342399e+08                32       @hmureithi, @kenyans  #MamaMbogaMoment
# 4.083459e+09             21114  @oleitumbi, @williamsruto  #MamaMbogaMoment
# 1.357592e+18             10073  @oleitumbi, @williamsruto  #MamaMbogaMoment
#
#                    total_monthly_visitors  twitter_followers  \
# twitter_author_id
# 1.342399e+08                   1414667000                 32
# 4.083459e+09                   1414667000              21114
# 1.357592e+18                   1414667000              10073
#
#                    twitter_following  twitter_tweets  reach_(new)
# twitter_author_id
# 1.342399e+08                     159             462            0
# 4.083459e+09                   15120          157903         7602
# 1.357592e+18                    1209           32910         4958

# %%
df.drop(['total_monthly_visitors'], axis = 1, inplace = True)

# %%
df.head(3)
# Out:
#                                                                title  \
# twitter_author_id
# 1.342399e+08       RT @HMureithi @Kenyans This is too low for a m...
# 4.083459e+09       RT @kilundeezy A good reminder  @OleItumbi  pa...
# 1.357592e+18       RT @kilundeezy A good reminder  @OleItumbi  pa...
#
#                                                            full_text  \
# twitter_author_id
# 1.342399e+08       RT @HMureithi @Kenyans This is too low for a m...
# 4.083459e+09       RT @kilundeezy A good reminder @OleItumbi pay ...
# 1.357592e+18       RT @kilundeezy A good reminder @OleItumbi pay ...
#
#                   sentiment emotion   region account_type        author  \
# twitter_author_id
# 1.342399e+08       negative     NaN      NaN   individual        mngesa
# 4.083459e+09        neutral     NaN  Nairobi   individual   Olang_Moses
# 1.357592e+18        neutral     NaN  Nairobi   individual  CaesarToreto
#
#                       city   gender  \
# twitter_author_id
# 1.342399e+08           NaN     male
# 4.083459e+09       Nairobi  unknown
# 1.357592e+18       Nairobi  unknown
#
#                                                             hashtags  impact  \
# twitter_author_id
# 1.342399e+08                                        #mamambogamoment     0.0
# 4.083459e+09       #mamambogamoment, #bottomupmuranga, #nyerinihu...    38.9
# 1.357592e+18       #mamambogamoment, #bottomupmuranga, #nyerinihu...    31.8
#
#                    impressions          mentioned_authors              tags  \
# twitter_author_id
# 1.342399e+08                32       @hmureithi, @kenyans  #MamaMbogaMoment
# 4.083459e+09             21114  @oleitumbi, @williamsruto  #MamaMbogaMoment
# 1.357592e+18             10073  @oleitumbi, @williamsruto  #MamaMbogaMoment
#
#                    twitter_followers  twitter_following  twitter_tweets  \
# twitter_author_id
# 1.342399e+08                      32                159             462
# 4.083459e+09                   21114              15120          157903
# 1.357592e+18                   10073               1209           32910
#
#                    reach_(new)
# twitter_author_id
# 1.342399e+08                 0
# 4.083459e+09              7602
# 1.357592e+18              4958

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2396 entries, 134239948.0 to 2931907132.0
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              2396 non-null   object
#  1   full_text          2396 non-null   object
#  2   sentiment          2396 non-null   object
#  3   emotion            1084 non-null   object
#  4   region             2128 non-null   object
#  5   account_type       2395 non-null   object
#  6   author             2396 non-null   object
#  7   city               2087 non-null   object
#  8   gender             2334 non-null   object
#  9   hashtags           2395 non-null   object
#  10  impact             2396 non-null   float64
#  11  impressions        2396 non-null   int64
#  12  mentioned_authors  1433 non-null   object
#  13  tags               2396 non-null   object
#  14  twitter_followers  2396 non-null   int64
#  15  twitter_following  2396 non-null   int64
#  16  twitter_tweets     2396 non-null   int64
#  17  reach_(new)        2396 non-null   int64
# dtypes: float64(1), int64(5), object(12)
# memory usage: 355.7+ KB

# %%
# instead of emotion use sentiment
df.drop(['emotion'], axis = 1, inplace=True)

# %%
# drop the missing values in the column city and region
df.dropna(subset = ['region'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2128 entries, 4083458907.0 to 68382599.0
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              2128 non-null   object
#  1   full_text          2128 non-null   object
#  2   sentiment          2128 non-null   object
#  3   region             2128 non-null   object
#  4   account_type       2128 non-null   object
#  5   author             2128 non-null   object
#  6   city               2087 non-null   object
#  7   gender             2071 non-null   object
#  8   hashtags           2128 non-null   object
#  9   impact             2128 non-null   float64
#  10  impressions        2128 non-null   int64
#  11  mentioned_authors  1264 non-null   object
#  12  tags               2128 non-null   object
#  13  twitter_followers  2128 non-null   int64
#  14  twitter_following  2128 non-null   int64
#  15  twitter_tweets     2128 non-null   int64
#  16  reach_(new)        2128 non-null   int64
# dtypes: float64(1), int64(5), object(11)
# memory usage: 299.2+ KB

# %%
df['city'].isnull().sum()
# Out:
# 41

# %%
df['city'] = df['city'].fillna('Unknown')

# %%
df['city'].value_counts()
# Out:
# city
# Nairobi     1668
# Nakuru        95
# Mombasa       92
# Eldoret       79
# Unknown       41
# Kisumu        28
# Thika         21
# Kakamega      17
# Meru          16
# Kisii         16
# Naivasha      10
# Nyeri          8
# Kericho        8
# Kilifi         8
# Machakos       7
# Nanyuki        7
# Kitale         4
# Malindi        2
# Embu           1
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (2128, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2128 entries, 4083458907.0 to 68382599.0
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              2128 non-null   object
#  1   full_text          2128 non-null   object
#  2   sentiment          2128 non-null   object
#  3   region             2128 non-null   object
#  4   account_type       2128 non-null   object
#  5   author             2128 non-null   object
#  6   city               2128 non-null   object
#  7   gender             2071 non-null   object
#  8   hashtags           2128 non-null   object
#  9   impact             2128 non-null   float64
#  10  impressions        2128 non-null   int64
#  11  mentioned_authors  1264 non-null   object
#  12  tags               2128 non-null   object
#  13  twitter_followers  2128 non-null   int64
#  14  twitter_following  2128 non-null   int64
#  15  twitter_tweets     2128 non-null   int64
#  16  reach_(new)        2128 non-null   int64
# dtypes: float64(1), int64(5), object(11)
# memory usage: 299.2+ KB

# %%
df.head(2)
# Out:
#                                                                title  \
# twitter_author_id
# 4.083459e+09       RT @kilundeezy A good reminder  @OleItumbi  pa...
# 1.357592e+18       RT @kilundeezy A good reminder  @OleItumbi  pa...
#
#                                                            full_text  \
# twitter_author_id
# 4.083459e+09       RT @kilundeezy A good reminder @OleItumbi pay ...
# 1.357592e+18       RT @kilundeezy A good reminder @OleItumbi pay ...
#
#                   sentiment   region account_type        author     city  \
# twitter_author_id
# 4.083459e+09        neutral  Nairobi   individual   Olang_Moses  Nairobi
# 1.357592e+18        neutral  Nairobi   individual  CaesarToreto  Nairobi
#
#                     gender                                           hashtags  \
# twitter_author_id
# 4.083459e+09       unknown  #mamambogamoment, #bottomupmuranga, #nyerinihu...
# 1.357592e+18       unknown  #mamambogamoment, #bottomupmuranga, #nyerinihu...
#
#                    impact  impressions          mentioned_authors  \
# twitter_author_id
# 4.083459e+09         38.9        21114  @oleitumbi, @williamsruto
# 1.357592e+18         31.8        10073  @oleitumbi, @williamsruto
#
#                                tags  twitter_followers  twitter_following  \
# twitter_author_id
# 4.083459e+09       #MamaMbogaMoment              21114              15120
# 1.357592e+18       #MamaMbogaMoment              10073               1209
#
#                    twitter_tweets  reach_(new)
# twitter_author_id
# 4.083459e+09               157903         7602
# 1.357592e+18                32910         4958

# %%
df['gender'] = df['gender'].replace('unknown', 'prefer not to say')
df['gender']  = df['gender'].fillna('prefer not to say')

# %%
df.head(5)
# Out:
#                                                                title  \
# twitter_author_id
# 4.083459e+09       RT @kilundeezy A good reminder  @OleItumbi  pa...
# 1.357592e+18       RT @kilundeezy A good reminder  @OleItumbi  pa...
# 7.296242e+17       RT @kilundeezy A good reminder  @OleItumbi  pa...
# 1.533716e+18       RT @kilundeezy A good reminder  @OleItumbi  pa...
# 1.524934e+18       RT @OleItumbi I am taking a 36 Hours break fro...
#
#                                                            full_text  \
# twitter_author_id
# 4.083459e+09       RT @kilundeezy A good reminder @OleItumbi pay ...
# 1.357592e+18       RT @kilundeezy A good reminder @OleItumbi pay ...
# 7.296242e+17       RT @kilundeezy A good reminder @OleItumbi pay ...
# 1.533716e+18       RT @kilundeezy A good reminder @OleItumbi pay ...
# 1.524934e+18       RT @OleItumbi I am taking a 36 Hours break fro...
#
#                   sentiment       region    account_type        author  \
# twitter_author_id
# 4.083459e+09        neutral      Nairobi      individual   Olang_Moses
# 1.357592e+18        neutral      Nairobi      individual  CaesarToreto
# 7.296242e+17        neutral      Nairobi  organisational  kirubimuigai
# 1.533716e+18        neutral  Rift Valley      individual   125__iconic
# 1.524934e+18        neutral  Rift Valley      individual     Bonniedes
#
#                       city             gender  \
# twitter_author_id
# 4.083459e+09       Nairobi  prefer not to say
# 1.357592e+18       Nairobi  prefer not to say
# 7.296242e+17       Nairobi  prefer not to say
# 1.533716e+18       Kericho  prefer not to say
# 1.524934e+18       Nanyuki  prefer not to say
#
#                                                             hashtags  impact  \
# twitter_author_id
# 4.083459e+09       #mamambogamoment, #bottomupmuranga, #nyerinihu...    38.9
# 1.357592e+18       #mamambogamoment, #bottomupmuranga, #nyerinihu...    31.8
# 7.296242e+17       #mamambogamoment, #bottomupmuranga, #nyerinihu...     0.0
# 1.533716e+18       #mamambogamoment, #bottomupmuranga, #nyerinihu...     0.0
# 1.524934e+18               #mamambogamoment, #hustlernation, #radico     2.3
#
#                    impressions          mentioned_authors              tags  \
# twitter_author_id
# 4.083459e+09             21114  @oleitumbi, @williamsruto  #MamaMbogaMoment
# 1.357592e+18             10073  @oleitumbi, @williamsruto  #MamaMbogaMoment
# 7.296242e+17               221  @oleitumbi, @williamsruto  #MamaMbogaMoment
# 1.533716e+18               342  @oleitumbi, @williamsruto  #MamaMbogaMoment
# 1.524934e+18              2024                          @  #MamaMbogaMoment
#
#                    twitter_followers  twitter_following  twitter_tweets  \
# twitter_author_id
# 4.083459e+09                   21114              15120          157903
# 1.357592e+18                   10073               1209           32910
# 7.296242e+17                     221                 34            8326
# 1.533716e+18                     342                183            1705
# 1.524934e+18                    2024               1795           37657
#
#                    reach_(new)
# twitter_author_id
# 4.083459e+09              7602
# 1.357592e+18              4958
# 7.296242e+17                 0
# 1.533716e+18                 0
# 1.524934e+18              1205

# %%
df.to_csv('cleaned_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2128 entries, 4083458907.0 to 68382599.0
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              2128 non-null   object
#  1   full_text          2128 non-null   object
#  2   sentiment          2128 non-null   object
#  3   region             2128 non-null   object
#  4   account_type       2128 non-null   object
#  5   author             2128 non-null   object
#  6   city               2128 non-null   object
#  7   gender             2128 non-null   object
#  8   hashtags           2128 non-null   object
#  9   impact             2128 non-null   float64
#  10  impressions        2128 non-null   int64
#  11  mentioned_authors  1264 non-null   object
#  12  tags               2128 non-null   object
#  13  twitter_followers  2128 non-null   int64
#  14  twitter_following  2128 non-null   int64
#  15  twitter_tweets     2128 non-null   int64
#  16  reach_(new)        2128 non-null   int64
# dtypes: float64(1), int64(5), object(11)
# memory usage: 299.2+ KB

# %%
df.drop(['mentioned_authors'], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2128 entries, 4083458907.0 to 68382599.0
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              2128 non-null   object
#  1   full_text          2128 non-null   object
#  2   sentiment          2128 non-null   object
#  3   region             2128 non-null   object
#  4   account_type       2128 non-null   object
#  5   author             2128 non-null   object
#  6   city               2128 non-null   object
#  7   gender             2128 non-null   object
#  8   hashtags           2128 non-null   object
#  9   impact             2128 non-null   float64
#  10  impressions        2128 non-null   int64
#  11  tags               2128 non-null   object
#  12  twitter_followers  2128 non-null   int64
#  13  twitter_following  2128 non-null   int64
#  14  twitter_tweets     2128 non-null   int64
#  15  reach_(new)        2128 non-null   int64
# dtypes: float64(1), int64(5), object(10)
# memory usage: 282.6+ KB

# %%
df.to_csv('clean_data.csv')

# %%
df.head()
# Out:
#                                                                title  \
# twitter_author_id
# 4.083459e+09       RT @kilundeezy A good reminder  @OleItumbi  pa...
# 1.357592e+18       RT @kilundeezy A good reminder  @OleItumbi  pa...
# 7.296242e+17       RT @kilundeezy A good reminder  @OleItumbi  pa...
# 1.533716e+18       RT @kilundeezy A good reminder  @OleItumbi  pa...
# 1.524934e+18       RT @OleItumbi I am taking a 36 Hours break fro...
#
#                                                            full_text  \
# twitter_author_id
# 4.083459e+09       RT @kilundeezy A good reminder @OleItumbi pay ...
# 1.357592e+18       RT @kilundeezy A good reminder @OleItumbi pay ...
# 7.296242e+17       RT @kilundeezy A good reminder @OleItumbi pay ...
# 1.533716e+18       RT @kilundeezy A good reminder @OleItumbi pay ...
# 1.524934e+18       RT @OleItumbi I am taking a 36 Hours break fro...
#
#                   sentiment       region    account_type        author  \
# twitter_author_id
# 4.083459e+09        neutral      Nairobi      individual   Olang_Moses
# 1.357592e+18        neutral      Nairobi      individual  CaesarToreto
# 7.296242e+17        neutral      Nairobi  organisational  kirubimuigai
# 1.533716e+18        neutral  Rift Valley      individual   125__iconic
# 1.524934e+18        neutral  Rift Valley      individual     Bonniedes
#
#                       city             gender  \
# twitter_author_id
# 4.083459e+09       Nairobi  prefer not to say
# 1.357592e+18       Nairobi  prefer not to say
# 7.296242e+17       Nairobi  prefer not to say
# 1.533716e+18       Kericho  prefer not to say
# 1.524934e+18       Nanyuki  prefer not to say
#
#                                                             hashtags  impact  \
# twitter_author_id
# 4.083459e+09       #mamambogamoment, #bottomupmuranga, #nyerinihu...    38.9
# 1.357592e+18       #mamambogamoment, #bottomupmuranga, #nyerinihu...    31.8
# 7.296242e+17       #mamambogamoment, #bottomupmuranga, #nyerinihu...     0.0
# 1.533716e+18       #mamambogamoment, #bottomupmuranga, #nyerinihu...     0.0
# 1.524934e+18               #mamambogamoment, #hustlernation, #radico     2.3
#
#                    impressions              tags  twitter_followers  \
# twitter_author_id
# 4.083459e+09             21114  #MamaMbogaMoment              21114
# 1.357592e+18             10073  #MamaMbogaMoment              10073
# 7.296242e+17               221  #MamaMbogaMoment                221
# 1.533716e+18               342  #MamaMbogaMoment                342
# 1.524934e+18              2024  #MamaMbogaMoment               2024
#
#                    twitter_following  twitter_tweets  reach_(new)
# twitter_author_id
# 4.083459e+09                   15120          157903         7602
# 1.357592e+18                    1209           32910         4958
# 7.296242e+17                      34            8326            0
# 1.533716e+18                     183            1705            0
# 1.524934e+18                    1795           37657         1205

# %%
data_copy = df.copy()

# %%
data_copy.head(2)
# Out:
#                                                                title  \
# twitter_author_id
# 4.083459e+09       RT @kilundeezy A good reminder  @OleItumbi  pa...
# 1.357592e+18       RT @kilundeezy A good reminder  @OleItumbi  pa...
#
#                                                            full_text  \
# twitter_author_id
# 4.083459e+09       RT @kilundeezy A good reminder @OleItumbi pay ...
# 1.357592e+18       RT @kilundeezy A good reminder @OleItumbi pay ...
#
#                   sentiment   region account_type        author     city  \
# twitter_author_id
# 4.083459e+09        neutral  Nairobi   individual   Olang_Moses  Nairobi
# 1.357592e+18        neutral  Nairobi   individual  CaesarToreto  Nairobi
#
#                               gender  \
# twitter_author_id
# 4.083459e+09       prefer not to say
# 1.357592e+18       prefer not to say
#
#                                                             hashtags  impact  \
# twitter_author_id
# 4.083459e+09       #mamambogamoment, #bottomupmuranga, #nyerinihu...    38.9
# 1.357592e+18       #mamambogamoment, #bottomupmuranga, #nyerinihu...    31.8
#
#                    impressions              tags  twitter_followers  \
# twitter_author_id
# 4.083459e+09             21114  #MamaMbogaMoment              21114
# 1.357592e+18             10073  #MamaMbogaMoment              10073
#
#                    twitter_following  twitter_tweets  reach_(new)
# twitter_author_id
# 4.083459e+09                   15120          157903         7602
# 1.357592e+18                    1209           32910         4958

# %%
# authors that contain the largest number of entries
# the data had most entries from the following people 
data_copy['author'].value_counts().nlargest(20)
# Out:
# author
# Jonngc            32
# SelinaTeyie       23
# miguelmuguchia    17
# azimio022         15
# GunnerAfrican     14
# kelvin_mwebia     14
# KipKalyaNoah      13
# tembeakenyaa      13
# kimarumainah      12
# DaView_k          10
# David___Mbugua    10
# OleItumbi         10
# Luciann254         9
# Mwaistanley2       9
# Ericmwa            9
# la_greatke         9
# MwaurahDrax        8
# NoelRotich         8
# sammy_macharia     8
# MastonKim1         8
# Name: count, dtype: int64

# %%
# data was mostly captured from these accounts
# authors with the highest entries(25)
top_25_authors = data_copy['author'].value_counts().nlargest(30)

# Create a bar graph
plt.figure(figsize=(12, 8))
top_25_authors.plot(kind='bar', color = 'lightblue')

# Add labels and title
plt.xlabel('Accounts')
plt.ylabel('Sum of Entries')
plt.title('Accounts With The Most Entries in the Dataset')
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# gender distribution of the dataset 
# Calculate gender distribution
gender_distribution = data_copy['gender'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(gender_distribution, labels=gender_distribution.index, autopct='%1.1f%%', colors=['#1b9e77', '#a9f971', '#fdaa48']) #'#66b3ff', '#99ff99', '#ffcc99'

# Add a title
plt.title('Gender Distribution')

# Save the plot as an image file
plt.savefig('gender_distribution.png') 

# Show the plot
plt.show()

# %%
df['city'].value_counts()
# Out:
# city
# Nairobi     1668
# Nakuru        95
# Mombasa       92
# Eldoret       79
# Unknown       41
# Kisumu        28
# Thika         21
# Kakamega      17
# Meru          16
# Kisii         16
# Naivasha      10
# Nyeri          8
# Kericho        8
# Kilifi         8
# Machakos       7
# Nanyuki        7
# Kitale         4
# Malindi        2
# Embu           1
# Name: count, dtype: int64

# %%
# Get the value counts for the 'city' column
city_counts = df['city'].value_counts().sort_values(ascending=True)

# Create a horizontal bar chart
plt.figure(figsize=(12, 8))
city_counts.plot(kind='barh', color='brown')

# Add labels and title
plt.xlabel('Total Entries')
plt.ylabel('City')
plt.title('City Distribution')

# Show the plot
plt.tight_layout()
plt.show()

# %%
df.head(3)
# Out:
#                                                                title  \
# twitter_author_id
# 4.083459e+09       RT @kilundeezy A good reminder  @OleItumbi  pa...
# 1.357592e+18       RT @kilundeezy A good reminder  @OleItumbi  pa...
# 7.296242e+17       RT @kilundeezy A good reminder  @OleItumbi  pa...
#
#                                                            full_text  \
# twitter_author_id
# 4.083459e+09       RT @kilundeezy A good reminder @OleItumbi pay ...
# 1.357592e+18       RT @kilundeezy A good reminder @OleItumbi pay ...
# 7.296242e+17       RT @kilundeezy A good reminder @OleItumbi pay ...
#
#                   sentiment   region    account_type        author     city  \
# twitter_author_id
# 4.083459e+09        neutral  Nairobi      individual   Olang_Moses  Nairobi
# 1.357592e+18        neutral  Nairobi      individual  CaesarToreto  Nairobi
# 7.296242e+17        neutral  Nairobi  organisational  kirubimuigai  Nairobi
#
#                               gender  \
# twitter_author_id
# 4.083459e+09       prefer not to say
# 1.357592e+18       prefer not to say
# 7.296242e+17       prefer not to say
#
#                                                             hashtags  impact  \
# twitter_author_id
# 4.083459e+09       #mamambogamoment, #bottomupmuranga, #nyerinihu...    38.9
# 1.357592e+18       #mamambogamoment, #bottomupmuranga, #nyerinihu...    31.8
# 7.296242e+17       #mamambogamoment, #bottomupmuranga, #nyerinihu...     0.0
#
#                    impressions              tags  twitter_followers  \
# twitter_author_id
# 4.083459e+09             21114  #MamaMbogaMoment              21114
# 1.357592e+18             10073  #MamaMbogaMoment              10073
# 7.296242e+17               221  #MamaMbogaMoment                221
#
#                    twitter_following  twitter_tweets  reach_(new)
# twitter_author_id
# 4.083459e+09                   15120          157903         7602
# 1.357592e+18                    1209           32910         4958
# 7.296242e+17                      34            8326            0

# %%
df.reset_index(inplace = True)

# %%
df['full_text']
# Out:
# 0       RT @kilundeezy A good reminder @OleItumbi pay ...
# 1       RT @kilundeezy A good reminder @OleItumbi pay ...
# 2       RT @kilundeezy A good reminder @OleItumbi pay ...
# 3       RT @kilundeezy A good reminder @OleItumbi pay ...
# 4       RT @OleItumbi I am taking a 36 Hours break fro...
#                               ...
# 2123    RT @OleItumbi The August 9, poll is a contest ...
# 2124    RT @OleItumbi The August 9, poll is a contest ...
# 2125    RT @OleItumbi The August 9, poll is a contest ...
# 2126    RT @OleItumbi The August 9, poll is a contest ...
# 2127    The August 9, poll is a contest between DP @Wi...
# Name: full_text, Length: 2128, dtype: object

# %%
df['full_text']
# Out:
# 0       RT @kilundeezy A good reminder @OleItumbi pay ...
# 1       RT @kilundeezy A good reminder @OleItumbi pay ...
# 2       RT @kilundeezy A good reminder @OleItumbi pay ...
# 3       RT @kilundeezy A good reminder @OleItumbi pay ...
# 4       RT @OleItumbi I am taking a 36 Hours break fro...
#                               ...
# 2123    RT @OleItumbi The August 9, poll is a contest ...
# 2124    RT @OleItumbi The August 9, poll is a contest ...
# 2125    RT @OleItumbi The August 9, poll is a contest ...
# 2126    RT @OleItumbi The August 9, poll is a contest ...
# 2127    The August 9, poll is a contest between DP @Wi...
# Name: full_text, Length: 2128, dtype: object

# %%
# @WilliamsRuto SMALL businesses is a MAJOR source of employment in Kenya. 
# Dr William Ruto's administration will VALUE, PROTECT and, SUPPORT all SMEs✊ 
# #KenyaKwanza #economy #Mitumba #mamambogamoment #bodaboda #graduates #teachers #medics #Farmers #TheFutureOfKenya"

# %%
# let's go ahead and analyze the tweets 
tweets_df = df[['full_text']].copy()
tweets_df
# Out:
#                                               full_text
# 0     RT @kilundeezy A good reminder @OleItumbi pay ...
# 1     RT @kilundeezy A good reminder @OleItumbi pay ...
# 2     RT @kilundeezy A good reminder @OleItumbi pay ...
# 3     RT @kilundeezy A good reminder @OleItumbi pay ...
# 4     RT @OleItumbi I am taking a 36 Hours break fro...
# ...                                                 ...
# 2123  RT @OleItumbi The August 9, poll is a contest ...
# 2124  RT @OleItumbi The August 9, poll is a contest ...
# 2125  RT @OleItumbi The August 9, poll is a contest ...
# 2126  RT @OleItumbi The August 9, poll is a contest ...
# 2127  The August 9, poll is a contest between DP @Wi...
#
# [2128 rows x 1 columns]

# %%
tweets_df.head()
# Out:
#                                            full_text
# 0  RT @kilundeezy A good reminder @OleItumbi pay ...
# 1  RT @kilundeezy A good reminder @OleItumbi pay ...
# 2  RT @kilundeezy A good reminder @OleItumbi pay ...
# 3  RT @kilundeezy A good reminder @OleItumbi pay ...
# 4  RT @OleItumbi I am taking a 36 Hours break fro...

# %%
import matplotlib.pyplot as plt

# Select a few random tweets
sample_tweets = df['full_text'].sample(n=10, random_state=1).tolist()

# Plot the sample tweets
plt.figure(figsize=(10, 6))
plt.barh(range(len(sample_tweets)), [len(tweet) for tweet in sample_tweets], color='skyblue')
plt.yticks(range(len(sample_tweets)), sample_tweets)
plt.xlabel('Length of Tweet')
plt.title('Sample Tweets and Their Lengths')
plt.show()

# %%
# lets first look at the tweet structure
# key components of publishing and posting the tweets
# looked at 10 tweets
# from this analysis found out there two key political figures : William Ruto & Raila Odinga
# the tweets tagged these political figures
# hashtags accompanied the tweets i.e #MamaMbogaMoment, #HustlerNation, #BabaNaMama
# Religion playing a key role in the general elections, it came up 
# identified one trend jacker 
# Oleitumbi was paying infuencers

# %%
# Define regex pattern to extract retweet usernames
pattern = r"RT\s+@(\w+)"

# Extract retweet usernames
extracted_usernames = tweets_df['full_text'].str.extractall(pattern)

# Reset index and handle potential duplicates
extracted_usernames = extracted_usernames.reset_index(level=0, drop=True)

# Count occurrences of each username
username_counts = extracted_usernames[0].value_counts()

# Create a DataFrame from the counts for better readability
most_retweeted_df = pd.DataFrame({'username': username_counts.index, 'count': username_counts.values})

# Sort by count to find the most retweeted users
most_retweeted_df = most_retweeted_df.sort_values(by='count', ascending=False)

# Display the DataFrame
most_retweeted_df
# Out:
#           username  count
# 0        OleItumbi    930
# 1       WanjikuHSC    118
# 2      NyoroNdindi     98
# 3      uda_hustler     55
# 4       liam_tweep     48
# ..             ...    ...
# 83   GunnerAfrican      1
# 84    Dennoh_kelly      1
# 86      mzinga_iko      1
# 87    PaulineNjau5      1
# 111  Beki_mfungaji      1
#
# [112 rows x 2 columns]

# %%
# most retweeted accounts often show
# most people agreeing with you
# let's visualize this
# Get the top 20 most retweeted users
top_20_most_retweeted_df = most_retweeted_df.head(20)

# Plot a horizontal bar chart
plt.figure(figsize=(12, 8))
plt.barh(top_20_most_retweeted_df['username'], top_20_most_retweeted_df['count'], color='firebrick')
plt.xlabel('No. of Retweets')
plt.ylabel('Username')
plt.title('Most Retweeted Accounts')
plt.gca().invert_yaxis()  # To show the highest counts at the top
plt.show()

# %%
# most influential accounts based on people retweeting them 
# people engaging with their content
# to also mean there are high chances of their content showing up on my feed

# %%
# Define regex pattern to extract tagged usernames
pattern = r"@(\w+)"

# Extract tagged usernames
extracted_usernames = tweets_df['full_text'].str.findall(pattern)

# Flatten the list of lists
flattened_usernames = [username for sublist in extracted_usernames for username in sublist]

# Count occurrences of each username
username_counts = pd.Series(flattened_usernames).value_counts()

# Create a DataFrame from the counts for better readability
tagged_accounts_df = pd.DataFrame({'username': username_counts.index, 'count': username_counts.values})

# Filter out accounts tagged 50 or fewer times
filtered_tagged_accounts_df = tagged_accounts_df[tagged_accounts_df['count'] > 30]

# Display the filtered DataFrame
print(filtered_tagged_accounts_df)

# Plot a horizontal bar chart of tagged accounts with more than 50 mentions
plt.figure(figsize=(16, 12))  # Increased figure size
plt.barh(filtered_tagged_accounts_df['username'], filtered_tagged_accounts_df['count'], color='lightgreen')
plt.xlabel('No. of Mentions')
plt.ylabel('Username')
plt.title('Tagged Accounts with more Than 30 Mentions ')
plt.gca().invert_yaxis()  # To show the highest counts at the top
plt.show()
# Out:
#           username  count
# 0        OleItumbi    946
# 1     WilliamsRuto    889
# 2      RailaOdinga    459
# 3   citizentvkenya    168
# 4       WanjikuHSC    118
# 5      NyoroNdindi     98
# 6        DCI_Kenya     73
# 7     NationAfrica     73
# 8      uda_hustler     55
# 9       liam_tweep     48
# 10        UDAKenya     36
# 11    F_M_Networks     35
# 12     MarthaKarua     35
# 13  DidmusWaBarasa     34
# 14  MWALIMU_AMUNGA     32

# %%
# Filter for specific press media accounts
press_media_accounts = ['citizentvkenya', 'NationAfrica']
filtered_press_media_df = filtered_tagged_accounts_df[filtered_tagged_accounts_df['username'].isin(press_media_accounts)]

# Display the filtered DataFrame
print(filtered_press_media_df)

# Plot a pie chart for the press media accounts
plt.figure(figsize=(8, 8))
plt.pie(filtered_press_media_df['count'], labels=filtered_press_media_df['username'], autopct='%1.1f%%', colors=['seagreen','gold'])
plt.title('Media Coverage')
plt.show()
# Out:
#          username  count
# 3  citizentvkenya    168
# 7    NationAfrica     73

# %%
import matplotlib.pyplot as plt

# Assuming filtered_tagged_accounts_df is your DataFrame with the necessary data

# Filter for specific press media accounts
press_media_accounts = ['citizentvkenya', 'NationAfrica']
filtered_press_media_df = filtered_tagged_accounts_df[filtered_tagged_accounts_df['username'].isin(press_media_accounts)]

# Rename the labels
label_mapping = {'citizentvkenya': 'Citizen TV', 'NationAfrica': 'Nation Africa'}
filtered_press_media_df['label'] = filtered_press_media_df['username'].map(label_mapping)

# Plot a pie chart for the press media accounts
plt.figure(figsize=(8, 8))
plt.pie(filtered_press_media_df['count'], labels=filtered_press_media_df['label'], autopct='%1.1f%%', colors=['seagreen', 'gold'])
plt.title('Media Coverage')
plt.show()
# Out:
# C:\Users\Atieno\AppData\Local\Temp\ipykernel_9816\1181466158.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_press_media_df['label'] = filtered_press_media_df['username'].map(label_mapping)

# %%
df.head(2)
# Out:
#    twitter_author_id                                              title  \
# 0       4.083459e+09  RT @kilundeezy A good reminder  @OleItumbi  pa...
# 1       1.357592e+18  RT @kilundeezy A good reminder  @OleItumbi  pa...
#
#                                            full_text sentiment   region  \
# 0  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral  Nairobi
# 1  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral  Nairobi
#
#   account_type        author     city             gender  \
# 0   individual   Olang_Moses  Nairobi  prefer not to say
# 1   individual  CaesarToreto  Nairobi  prefer not to say
#
#                                             hashtags  impact  impressions  \
# 0  #mamambogamoment, #bottomupmuranga, #nyerinihu...    38.9        21114
# 1  #mamambogamoment, #bottomupmuranga, #nyerinihu...    31.8        10073
#
#                tags  twitter_followers  twitter_following  twitter_tweets  \
# 0  #MamaMbogaMoment              21114              15120          157903
# 1  #MamaMbogaMoment              10073               1209           32910
#
#    reach_(new)
# 0         7602
# 1         4958

# %%
from wordcloud import WordCloud

# Combine all hashtags into a single string
all_hashtags = ' '.join(df['hashtags'].tolist())

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_hashtags)

# Plot the WordCloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide the axis
plt.show()

# %%
import pandas as pd
import re
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Define the regex pattern to find mentions of @Oleitumbi
pattern = r'@Oleitumbi'

# Sample DataFrame setup (replace this with your actual DataFrame)
# df = pd.DataFrame({'full_text': [...]})

# Filter tweets that mention @Oleitumbi
mentioned_tweets = df[df['full_text'].str.contains(pattern, case=False, na=False)]

# Check if there are any tweets mentioning @Oleitumbi
if not mentioned_tweets.empty:
    # Combine all tweets mentioning @Oleitumbi into a single string
    all_mentions = ' '.join(mentioned_tweets['full_text'].dropna().tolist())

    # Create a WordCloud object
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_mentions)

    # Plot the WordCloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')  # Hide the axis
    plt.title('Word Cloud for Tweets Mentioning @Oleitumbi')
    plt.show()
else:
    print("No tweets mentioning @Oleitumbi were found.")

# %%
df['full_text'].iloc[1]
# Out:
# 'RT @kilundeezy A good reminder @OleItumbi pay Influencers.@WilliamsRuto 20/05/2022 #MamaMbogamoment 21/05/2022 #BottomUpMuranga 21/05/2022 #NyeriNiHustlerNation 23/05/2023 #BottomUpKiambu 24/05/2022 #BottomUpTaitaTaveta 25/05/2022 #TheEconomyFirst 26/05/2022 #PlanNiBottomUp'
